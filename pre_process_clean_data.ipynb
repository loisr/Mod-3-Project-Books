# %% [markdown]
# This notebook reads in all the books and pre-processes them to be ready to run different ML models on the data. It then exports this data to a csv to upload into other notebooks for said analysis.

# %%
# import all need libaries 
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()

# %%
# class that processes each book
class Book():
    
    _all_books = []
    
    def __init__(self,filepath):
        # assigns title and author
        self.title = filepath.split('/')[1].rstrip('.txt')
        self.author = filepath.split('/')[0]
        
    def read(self):
        # opens the actual file
        with open(filepath) as f:
            self.text = f.readlines()
            
    def process(self):
        # cleans book, takes out punctuation and formating 
        self.cleaned_book = []
        for line in self.text:
            for symbol in """“”<>{}[]&*^%$#@~`_+=-""'':;(),.?!''\n""":
                line = line.replace(symbol, '').lower()
            self.cleaned_book.append(line)
        
    def tokenize(self):
        # tokenize and remove stopwords
        joined_book = ' '.join(self.cleaned_book)
        tokenized_book = word_tokenize(joined_book)
        stop_words=set(stopwords.words("english"))
        self.filtered_book = []
        for w in tokenized_book:
            if w not in stop_words:
                self.filtered_book.append(w)
        
    def lemmatize(self):
        # lemmatize the text
        self.lemmatized_book=[]
        for w in self.filtered_book:
            self.lemmatized_book.append(lemmatizer.lemmatize(w))
               
    def add_book(self):
        # adds each book to list of dictionaries of all books
        Book._all_books.append({
            'title':self.title,
            'author':self.author,
            'text':self.lemmatized_book,
        })
    
    @classmethod
    def all_books(cls):
        return pd.DataFrame(cls._all_books)[['author','title','text']]

# %%
# import and clean list of book .txt files, use bash to make a list and clean this part according to your needs below
f = open("list.txt", "r")
path_list = f.readlines()
path_list = [i.replace("/Users/<myname>/mod3_project/","") for i in path_list]
path_list = [i.replace("\n","") for i in path_list]

# %%
# reads in all books and runs them thru the Book class
for filepath in path_list:
    i = Book(filepath)
    print(filepath)
    i.read()
    i.process()
    i.tokenize()
    i.lemmatize()
    i.add_book()
# Out:
# austen/Emma-JA.txt
# austen/LS-JA.txt
# austen/Mansfield-JA.txt
# austen/Northranger_Abbey-JA.txt
# austen/PP_JA.txt
# austen/Persuasion-JA.txt
# austen/SS-JA.txt
# dickens/dickens-american-631.txt
# dickens/dickens-battle-630.txt
# dickens/dickens-childs-629-copy.txt
# dickens/dickens-chimes-379.txt
# dickens/dickens-christmas-125.txt
# dickens/dickens-cricket-127.txt
# dickens/dickens-david-626.txt
# dickens/dickens-dombey-622.txt
# dickens/dickens-hard-625.txt
# dickens/dickens-haunted-633.txt
# dickens/dickens-holiday-623.txt
# dickens/dickens-hunted-624.txt
# dickens/dickens-master-634.txt
# dickens/dickens-mystery-636.txt
# dickens/dickens-old-628.txt
# dickens/dickens-oliver-627.txt
# dickens/dickens-pickwick-635.txt
# dickens/dickens-pictures-632.txt
# dickens/dickens-tale-126.txt
# doyle/agrange.txt
# doyle/b-p_plan.txt
# doyle/bascombe.txt
# doyle/beryl.txt
# doyle/blanced.txt
# doyle/blkpeter.txt
# doyle/bluecar.txt
# doyle/cardbox.txt
# doyle/caseide.txt
# doyle/charles.txt
# doyle/copper.txt
# doyle/creeping.txt
# doyle/crookman.txt
# doyle/danceman.txt
# doyle/devilsf.txt
# doyle/doyle-hound-383.txt
# doyle/doyle-lost-385.txt
# doyle/doyle-study-390.txt
# doyle/dyingdec.txt
# doyle/finalpro.txt
# doyle/illustr.txt
# emerson/emerson-american-227.txt
# emerson/emerson-conduct-228.txt
# emerson/emerson-conservative-229.txt
# emerson/emerson-english-230.txt
# emerson/emerson-essays-231.txt
# emerson/emerson-essays-232.txt
# emerson/emerson-lecture-233.txt
# emerson/emerson-literary-234.txt
# emerson/emerson-man-235.txt
# emerson/emerson-method-236.txt
# emerson/emerson-transcendentalist-239.txt
# emerson/emerson-young-241.txt
# hawthorne/hawthorne-artist-458.txt
# hawthorne/hawthorne-birthmark-459.txt
# hawthorne/hawthorne-great-466.txt
# hawthorne/hawthorne-house-64.txt
# hawthorne/hawthorne-lady-472.txt
# hawthorne/hawthorne-ministers-473.txt
# hawthorne/hawthorne-old-462.txt
# hawthorne/hawthorne-prophetic-476.txt
# hawthorne/hawthorne-scarlet-63.txt
# hawthorne/hawthorne-wedding-480.txt
# keats/keats-character-482.txt
# keats/keats-day-504.txt
# keats/keats-endymion-484.txt
# keats/keats-hyperion-487.txt
# keats/keats-isabella-490.txt
# keats/keats-o-492.txt
# keats/keats-ode-495.txt
# keats/keats-on-497.txt
# keats/keats-on-499.txt
# keats/keats-on-500.txt
# keats/keats-poet-506.txt
# keats/keats-sleep-502.txt
# keats/keats-stanzas-503.txt
# keats/keats-to-508.txt
# keats/keats-to-510.txt
# keats/keats-to-511.txt
# keats/keats-when-513.txt
# melville/1900-0.txt
# melville/moby10b.txt
# melville/pg10712.txt
# melville/pg11231.txt
# melville/pg12384.txt
# melville/pg13720.txt
# melville/pg13721.txt
# melville/pg15859.txt
# melville/pg34970.txt
# melville/pg4045.txt
# milton/milton-another-517.txt
# milton/milton-comus-521.txt
# milton/milton-lycidas-524.txt
# milton/milton-on-525.txt
# milton/milton-on-527.txt
# milton/milton-on-531.txt
# milton/milton-paradise-108.txt
# milton/milton-paradise-219.txt
# milton/milton-passion-538.txt
# milton/milton-samson-534.txt
# milton/milton-sonnets-536.txt
# milton/milton-upon-542.txt
# poe/alone.txt
# poe/atale.txt
# poe/blackcat.txt
# poe/eleonora.txt
# poe/masque_r.txt
# poe/poe-bells-669.txt
# poe/poe-city-673.txt
# poe/poe-colloquy-675.txt
# poe/poe-descent-418.txt
# poe/poe-fall-682.txt
# poe/poe-four-443.txt
# poe/poe-lionizing-453.txt
# poe/poe-mystification-561.txt
# poe/poe-pit-110.txt
# poe/poe-raven-702.txt
# poe/poe-some-657.txt
# poe/poe-why-724.txt
# shakespeare/AMidsummerNightsDream.txt
# shakespeare/AllsWellThatEndsWell.txt
# shakespeare/AnthonyAndCleopatra.txt
# shakespeare/AsYouLikeIt.txt
# shakespeare/ComedyOfErrors.txt
# shakespeare/Coriolanus.txt
# shakespeare/Cymbeline.txt
# shakespeare/Hamlet.txt
# shakespeare/JuliusCaesar.txt
# shakespeare/KingHenry4_1.txt
# shakespeare/KingHenry4_2.txt
# shakespeare/KingHenry5.txt
# shakespeare/KingHenry6_1.txt
# shakespeare/KingHenry6_2.txt
# shakespeare/KingHenry6_3.txt
# shakespeare/KingHenry8.txt
# shakespeare/KingJohn.txt
# shakespeare/KingLear.txt
# shakespeare/KingRichard2.txt
# shakespeare/KingRichard3.txt
# shakespeare/LovesLaboursLost.txt
# shakespeare/MacBeth.txt
# shakespeare/MeasureForMeasure.txt
# shakespeare/MerchantOfVenice.txt
# shakespeare/MerryWivesOfWindsor.txt
# shakespeare/MuchAdoAboutNothing.txt
# shakespeare/Othello.txt
# shakespeare/RomeoAndJuliet.txt
# shakespeare/TamingOfTheShrew.txt
# shakespeare/Tempest.txt
# shakespeare/TimonOfAthens.txt
# shakespeare/TitusAndronicus.txt
# shakespeare/TroilusAndCressida.txt
# shakespeare/TwelfthNight.txt
# shakespeare/TwoGentlemenOfVerona.txt
# shakespeare/WintersTale.txt
# shakespeare/pg1041.txt
# twain/abroad.txt
# twain/beqst11.txt
# twain/ghost.txt
# twain/hfinn10.txt
# twain/lmiss10.txt
# twain/onanism.txt
# twain/prince_pauper.txt
# twain/pud_head.txt
# twain/twain-adventures-27.txt
# twain/twain-connecticut-31.txt
# twain/twain-political-38.txt
# twain/twain-tramp-41.txt
# twain/twain-what-42.txt
# twain/warpryer.txt
# wilde/wilde-ballad-611.txt
# wilde/wilde-burden-612.txt
# wilde/wilde-charmides-601.txt
# wilde/wilde-eleutheria-602.txt
# wilde/wilde-flower-603.txt
# wilde/wilde-flowers-604.txt
# wilde/wilde-fourth-613.txt
# wilde/wilde-garden-614.txt
# wilde/wilde-humanitad-605.txt
# wilde/wilde-impressions-606.txt
# wilde/wilde-miscellaneous-607.txt
# wilde/wilde-panthea-608.txt
# wilde/wilde-picture-615.txt
# wilde/wilde-ravenna-609.txt
# wilde/wilde-rosa-610.txt
# wilde/wilde-sphinx-616.txt
# wilde/wilde-wind-617.txt

# %%
# just to check all the data and make sure that it looks ok
Book.all_books()
# Out:
#       author                    title  \
# 0     austen                  Emma-JA
# 1     austen                    LS-JA
# 2     austen             Mansfield-JA
# 3     austen     Northranger_Abbey-JA
# 4     austen                    PP_JA
# 5     austen            Persuasion-JA
# 6     austen                    SS-JA
# 7    dickens     dickens-american-631
# 8    dickens       dickens-battle-630
# 9    dickens  dickens-childs-629-copy
# 10   dickens       dickens-chimes-379
# 11   dickens    dickens-christmas-125
# 12   dickens      dickens-cricket-127
# 13   dickens        dickens-david-626
# 14   dickens       dickens-dombey-622
# 15   dickens         dickens-hard-625
# 16   dickens      dickens-haunted-633
# 17   dickens      dickens-holiday-623
# 18   dickens       dickens-hunted-624
# 19   dickens       dickens-master-634
# 20   dickens      dickens-mystery-636
# 21   dickens          dickens-old-628
# 22   dickens       dickens-oliver-627
# 23   dickens     dickens-pickwick-635
# 24   dickens     dickens-pictures-632
# 25   dickens         dickens-tale-126
# 26     doyle                  agrange
# 27     doyle                 b-p_plan
# 28     doyle                 bascombe
# 29     doyle                    beryl
# ..       ...                      ...
# 163    twain                  beqst11
# 164    twain                     ghos
# 165    twain                  hfinn10
# 166    twain                  lmiss10
# 167    twain                  onanism
# 168    twain            prince_pauper
# 169    twain                 pud_head
# 170    twain      twain-adventures-27
# 171    twain     twain-connecticut-31
# 172    twain       twain-political-38
# 173    twain           twain-tramp-41
# 174    twain            twain-what-42
# 175    twain                 warpryer
# 176    wilde         wilde-ballad-611
# 177    wilde         wilde-burden-612
# 178    wilde      wilde-charmides-601
# 179    wilde     wilde-eleutheria-602
# 180    wilde         wilde-flower-603
# 181    wilde        wilde-flowers-604
# 182    wilde         wilde-fourth-613
# 183    wilde         wilde-garden-614
# 184    wilde      wilde-humanitad-605
# 185    wilde    wilde-impressions-606
# 186    wilde  wilde-miscellaneous-607
# 187    wilde        wilde-panthea-608
# 188    wilde        wilde-picture-615
# 189    wilde        wilde-ravenna-609
# 190    wilde           wilde-rosa-610
# 191    wilde         wilde-sphinx-616
# 192    wilde           wilde-wind-617
#
#                                                   text
# 0    [volume, chapter, emma, woodhouse, handsome, c...
# 1    [lady, susan, vernon, mr, vernon, langford, de...
# 2    [chapter, thirty, year, ago, miss, maria, ward...
# 3    [advertisement, authoress, northanger, abbey, ...
# 4    [chapter, 1, truth, universally, acknowledged,...
# 5    [chapter, 1, sir, walter, elliot, kellynch, ha...
# 6    [chapter, 1, family, dashwood, long, settled, ...
# 7    [chapter, going, away, shall, never, forget, o...
# 8    [chapter, part, first, upon, time, matter, lit...
# 9    [chapter, ancient, england, roman, look, map, ...
# 10   [chime, first, quarter, many, people, desirabl...
# 11   [stave, 1, marley, ghost, marley, dead, begin,...
# 12   [chirp, first, kettle, began, dont, tell, mr, ...
# 13   [chapter, 1, born, whether, shall, turn, hero,...
# 14   [chapter, 1, dombey, son, dombey, sat, corner,...
# 15   [book, first, sowing, chapter, one, thing, nee...
# 16   [chapter, gift, bestowed, everybody, said, far...
# 17   [part, introductory, romance, prom, pen, willi...
# 18   [u, see, romance, life, capacity, chief, manag...
# 19   [chapter, master, humphrey, clockside, chimney...
# 20   [chapter, dawn, ancient, english, cathedral, t...
# 21   [chapter, 1, night, generally, time, walking, ...
# 22   [chapter, treat, place, oliver, twist, born, c...
# 23   [chapter, pickwickians, first, ray, light, ill...
# 24   [picture, italy, reader, passport, reader, vol...
# 25   [period, best, time, worst, time, age, wisdom,...
# 26   [bitterly, cold, night, frosty, morning, towar...
# 27   [third, week, november, year, 1895, dense, yel...
# 28   [seated, breakfast, one, morning, wife, maid, ...
# 29   [holmes, said, stood, one, morning, bowwindow,...
# ..                                                 ...
# 163  [30000, bequest, dog, tale, heaven, hell, cure...
# 164  [ghost, story, took, large, room, far, broadwa...
# 165  [explanatory, book, number, dialect, used, wit...
# 166  [body, nation, basin, mississippi, body, natio...
# 167  [one, evening, paris, 1879, stomach, club, soc...
# 168  [preface, set, tale, told, one, father, latter...
# 169  [whisper, reader, character, howsoever, good, ...
# 170  [dedication, wife, book, affectionately, dedic...
# 171  [connecticut, yankee, king, arthur, court, wor...
# 172  [political, economy, political, economy, basis...
# 173  [chapter, knighted, knave, bergen, one, day, o...
# 174  [man, machine, b, personal, merit, old, man, y...
# 175  [time, great, exalting, excitement, country, a...
# 176  [wear, scarlet, coat, blood, wine, red, blood,...
# 177  [english, thames, holier, far, rome, harebell,...
# 178  [grecian, lad, coming, home, pulpy, fig, wine,...
# 179  [sonnet, liberty, love, thy, child, whose, dul...
# 180  [sweet, blame, mine, fault, made, common, clay...
# 181  [le, silhouette, sea, flecked, bar, gray, dull...
# 182  [le, reveillon, sky, laced, fitful, red, circl...
# 183  [full, summer, heart, june, yet, sunburnt, rea...
# 184  [full, winter, tree, bare, save, cattle, huddl...
# 185  [silent, room, heavy, creeping, shade, dead, t...
# 186  [thou, knowest, seek, vain, land, till, sow, s...
# 187  [nay, let, u, walk, fire, unto, fire, passiona...
# 188  [chapter, studio, filled, rich, odour, rose, l...
# 189  [year, ago, breathed, italian, air, yet, methi...
# 190  [hela, drift, every, passion, till, soul, stri...
# 191  [dim, corner, room, longer, fancy, think, beau...
# 192  [impression, du, matin, thames, nocturne, blue...
#
# [193 rows x 3 columns]

# %%
# exports all books to one csv for use in other notebooks for analysis
Book.all_books().to_csv('all_books.csv')

# %%
df = Book.all_books()
